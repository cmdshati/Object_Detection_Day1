# %% [markdown]
# <a href="https://colab.research.google.com/github/cmdshati/Object_Detection_Day1/blob/main/Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo11n.pt")  #Object Detection model

# %%
result = model("/content/UYYqo.jpg")
# Out:
# image 1/1 /content/UYYqo.jpg: 640x640 1 banana, 2 apples, 10.4ms
# Speed: 3.6ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
result[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model2 = YOLO("yolo11n.pt")

# %%
result2 = model2("/content/download.jpg")
# Out:
# image 1/1 /content/download.jpg: 640x608 1 tv, 1 laptop, 1 clock, 27.0ms
# Speed: 8.2ms preprocess, 27.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 608)

# %%
result2[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=217x232>
